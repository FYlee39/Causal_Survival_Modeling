# %%
import pandas as pd
import numpy as np

from helper_functions import *
from sklearn.model_selection import ParameterGrid
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from scipy.stats import expon, uniform

RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)

# %%
# Sample size
n = 1000

# Number of covariates
n_linear = 3
n_non_linear = 3
n_categorical = 3



num_covariates = (n_linear, n_non_linear, n_categorical)

num_latent_group = 3

num_simulation = 100

save_dict = {}

# %%
CoxPH_estimated = []
CoxPH_IPTW_estimated = []
PSM_CoxPH_estimated = []
DCM_latent_estimated = []
DCM_total_estimated = []
DSM_estimated = []

# %%
from statsmodels.duration.hazard_regression import PHReg

# Function to fit Cox PH model
def fit_cox_model(data):
    exog = data.drop(["time", "event"], axis=1)
    model = PHReg(endog=data["time"], exog=exog, status=data["event"])
    result = model.fit()
    return result

# %%
import statsmodels.api as sm

# Function to fit IPTW with Cox PH model
def fit_iptw_cox_model(data):
    # Step 1: Fit logistic regression for propensity scores (P(treatment=1 | X))
    exog_logit = sm.add_constant(data.drop(["treatment", "time", "event"], axis=1))  # Add intercept
    logit_model = sm.Logit(data["treatment"], exog_logit)
    logit_result = logit_model.fit(disp=0)  # disp=0 to suppress output

    # Predict propensity scores
    ps = logit_result.predict(exog_logit)

    # Step 2: Compute IPTW weights
    # Stabilized weights: weight = treatment / ps + (1 - treatment) / (1 - ps)
    weights = data["treatment"] / ps + (1 - data["treatment"]) / (1 - ps)

    # Step 3: Fit weighted Cox PH model (only include treatment as covariate, since confounding is handled by weights)
    exog_cox = data[["treatment"]]
    cox_model = PHReg(endog=data["time"], exog=exog_cox, status=data["event"], weights=weights)
    cox_result = cox_model.fit()

    return cox_result

# %%
from scipy.spatial import KDTree

# Function to fit PSM with Cox PH model (1:1 nearest neighbor matching with caliper)
def fit_psm_cox_model(data, caliper=0.05):
    # Step 1: Fit logistic regression for propensity scores (P(treatment=1 | X))
    exog_logit = sm.add_constant(data.drop(["treatment", "time", "event"], axis=1))  # Add intercept
    logit_model = sm.Logit(data["treatment"], exog_logit)
    logit_result = logit_model.fit(disp=0)  # disp=0 to suppress output

    # Predict propensity scores
    data["ps"] = logit_result.predict(exog_logit)

    # Separate treated and controls
    treated = data[data["treatment"] == 1].copy()
    controls = data[data["treatment"] == 0].copy()

    # Build KDTree for controls' PS (reshape to 2D)
    controls_ps = controls["ps"].values.reshape(-1, 1)
    tree = KDTree(controls_ps)

    # Match each treated to nearest control within caliper
    matched_indices = []
    used_controls = set()

    for idx_t, row_t in treated.iterrows():
        ps_t = row_t["ps"].reshape(1, -1)
        dist, idx_c = tree.query(ps_t)
        idx_c = idx_c[0]  # query returns array

        if dist <= caliper and idx_c not in used_controls:
            matched_indices.append(controls.iloc[idx_c].name)  # Original index
            used_controls.add(idx_c)

    # Get matched controls
    matched_controls = controls.loc[matched_indices]

    # Combine matched treated and controls
    matched_data = pd.concat([treated, matched_controls])

    # Drop 'ps' column if not needed
    matched_data = matched_data.drop(columns=["ps"])

    # Step 3: Fit Cox PH model on matched data (only treatment as covariate)
    exog_cox = matched_data[["treatment"]]
    cox_model = PHReg(endog=matched_data["time"], exog=exog_cox, status=matched_data["event"])
    cox_result = cox_model.fit()

    return cox_result

# %%
for i in range(num_simulation):
    df, save_dict, lambda0, lambda1 = generate_simulated_data(num_sample=n,
                                 num_group=num_latent_group,
                                 num_covariates=num_covariates,
                                 **save_dict)

    """
    Cox PH model
    """
    result = fit_cox_model(df)
    CoxPH_estimated.append(result.params[0])

    """
    Cox PH model with IPTW
    """
    result = fit_iptw_cox_model(df)
    CoxPH_IPTW_estimated.append(result.params[0])

    """
    PSM with Cox PH model
    """
    result = fit_psm_cox_model(df)
    PSM_CoxPH_estimated.append(result.params[0])

    """
    DCM model
    """
    categorical_covariates = list(df.columns[n_linear + n_non_linear: n_linear + n_non_linear + n_categorical])
    # Data preparation
    cleaned_df = df.copy()

    # Extract treatment
    treatment = cleaned_df["treatment"]

    # Names of all categorical features
    processed_list = categorical_covariates

    # Exclude treatment during the training
    cleaned_df.drop("treatment", axis=1, inplace=True)

    # Processed data for DCM
    X_data_DCM, t_data_DCM, e_data_DCM, categorical_features_list_DCM, numerical_features_list_DCM = (
        processing_data_2_DCM(df=cleaned_df,
                              categorical_features_list=processed_list,
                              train_test_val_size=(0.7, 0.2, 0.1),
                              random_seed=RANDOM_SEED,
                              clustering=False,  # No need to cluster
                              )
    )

    X_train_DCM, X_val_DCM, X_test_DCM = X_data_DCM
    t_train_DCM, t_val_DCM, t_test_DCM = t_data_DCM
    e_train_DCM, e_val_DCM, e_test_DCM = e_data_DCM

    whole_X_set_DCM = pd.concat([X_train_DCM, X_val_DCM, X_test_DCM], axis=0)
    whole_t_set_DCM = pd.concat([t_train_DCM, t_val_DCM, t_test_DCM], axis=0)
    whole_e_set_DCM = pd.concat([e_train_DCM, e_val_DCM, e_test_DCM], axis=0)

    covariates_DCM = list(whole_X_set_DCM.columns)

    # Resample data with IPTW
    df_ps_DCM = pd.concat([whole_X_set_DCM, treatment], axis=1)

    df_ps_DCM = compute_PS_and_IPTW(df=df_ps_DCM,
                                covariates=covariates_DCM,
                                treatment="treatment")

    prob_DCM = df_ps_DCM["iptw_weight"] / df_ps_DCM["iptw_weight"].sum()

    resampled_indices_DCM = np.random.choice(len(df_ps_DCM), size=len(df_ps_DCM), replace=True, p=prob_DCM)

    x_resampled_DCM = whole_X_set_DCM.values[resampled_indices_DCM]
    t_resampled_DCM = whole_t_set_DCM.values[resampled_indices_DCM]
    e_resampled_DCM = whole_e_set_DCM.values[resampled_indices_DCM]
    treatment_resampled_DCM = treatment.values[resampled_indices_DCM]

    x_resampled_df_DCM = pd.DataFrame(x_resampled_DCM, columns=whole_X_set_DCM.columns)
    t_resampled_df_DCM = pd.DataFrame(t_resampled_DCM, columns=["time"])
    e_resampled_df_DCM = pd.DataFrame(e_resampled_DCM, columns=["event"])
    treatment_resampled_df_DCM = pd.DataFrame(treatment_resampled_DCM, columns=["treatment"])

    df_resampled_DCM = pd.concat([x_resampled_df_DCM,
                                 t_resampled_df_DCM,
                                 e_resampled_df_DCM,
                                 treatment_resampled_df_DCM],
                                axis=1
                                )

    # DCM hyper-parameters
    DCM_param_grid = {"k" : [3],
                      "learning_rate" : [1e-3],
                      "layers": [[50, 50]],
                      "iters": [100]
                 }
    DCM_params = ParameterGrid(DCM_param_grid)

    # Define and train DCM model
    dcm_wrap = DCM_Wrapper(DCM_params)

    dcm_wrap.fit(train_set=[df_resampled_DCM[covariates_DCM],
                            df_resampled_DCM["time"],
                            df_resampled_DCM["event"]]
                 )

    dcm_model = dcm_wrap.model

    train_latent_DCM = dcm_model.predict_latent_z(df_resampled_DCM[covariates_DCM])

    train_group_DCM = np.argmax(train_latent_DCM, axis=1)

    dcm_causal_effects_latent = plot_avg_survival_curve(df=df_resampled_DCM,
                                                        group_index=train_group_DCM,
                                                        model_wrapper=dcm_wrap,
                                                        covariates=covariates_DCM,
                                                        treatment="treatment",
                                                        num_time=1000,
                                                        show_figure=False
                                                        )

    DCM_latent_estimated.append(dcm_causal_effects_latent)

    dcm_causal_effects_total = plot_avg_survival_curve(df=df_resampled_DCM,
                                                       group_index=np.zeros_like(train_group_DCM),
                                                       model_wrapper=dcm_wrap,
                                                       covariates=covariates_DCM,
                                                       treatment="treatment",
                                                       num_time=1000,
                                                       given_title="Total Survival Curve (Treated v.s. Untreated)",
                                                       show_figure=False
                                                       )

    DCM_total_estimated.append(dcm_causal_effects_total[0])

    """
    DSM model
    """
    df_resampled_DSM = df_resampled_DCM
    covariates_DSM = covariates_DCM

    # DSM hyper-parameters
    DSM_param_grid = {"distribution": ["Weibull"],
                      "k": [3],
                      "layers": [[50, 50]],
                      "learning_rate": [1e-3],
                      "iters": [100]
                 }
    DSM_params = ParameterGrid(DSM_param_grid)

    # Define and train DCM model
    dsm_wrap = DSM_Wrapper(DSM_params)

    dsm_wrap.fit(train_set=[df_resampled_DSM[covariates_DSM],
                            df_resampled_DCM["time"],
                            df_resampled_DSM["event"]]
                 )

    dsm_causal_effects = plot_avg_survival_curve(df=df_resampled_DSM,
                                                group_index=np.zeros_like(train_group_DCM),
                                                model_wrapper=dsm_wrap,
                                                covariates=covariates_DSM,
                                                treatment="treatment",
                                                num_time=1000,
                                                given_title="Survival Curve (Treated v.s. Untreated)",
                                                show_figure=False
                                                )

    DSM_estimated.append(dsm_causal_effects)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   3%|▎         | 3/100 [00:00<00:03, 29.32it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#  45%|████▌     | 45/100 [00:02<00:02, 19.17it/s]
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Python_Project\Causal_Survival_Modeling\Test_Paper\helper_functions.py:466: RuntimeWarning: Mean of empty slice
#   S1_avg = np.nanmean(S1, axis=0)
# C:\My_Programs\Python_Project\Causal_Survival_Modeling\Test_Paper\helper_functions.py:467: RuntimeWarning: Mean of empty slice
#   S0_avg = np.nanmean(S0, axis=0)
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Python_Project\Causal_Survival_Modeling\Test_Paper\helper_functions.py:466: RuntimeWarning: Mean of empty slice
#   S1_avg = np.nanmean(S1, axis=0)
# C:\My_Programs\Python_Project\Causal_Survival_Modeling\Test_Paper\helper_functions.py:467: RuntimeWarning: Mean of empty slice
#   S0_avg = np.nanmean(S0, axis=0)
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Python_Project\Causal_Survival_Modeling\Test_Paper\helper_functions.py:466: RuntimeWarning: Mean of empty slice
#   S1_avg = np.nanmean(S1, axis=0)
# C:\My_Programs\Python_Project\Causal_Survival_Modeling\Test_Paper\helper_functions.py:467: RuntimeWarning: Mean of empty slice
#   S0_avg = np.nanmean(S0, axis=0)
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Python_Project\Causal_Survival_Modeling\Test_Paper\helper_functions.py:466: RuntimeWarning: Mean of empty slice
#   S1_avg = np.nanmean(S1, axis=0)
# C:\My_Programs\Python_Project\Causal_Survival_Modeling\Test_Paper\helper_functions.py:467: RuntimeWarning: Mean of empty slice
#   S0_avg = np.nanmean(S0, axis=0)
#   2%|▏         | 197/10000 [00:00<00:10, 943.50it/s]
#  26%|██▌       | 26/100 [00:02<00:06, 10.99it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   6%|▌         | 6/100 [00:00<00:03, 27.89it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:00<00:03, 26.82it/s]
#   2%|▏         | 162/10000 [00:00<00:04, 2069.03it/s]
#   5%|▌         | 5/100 [00:00<00:04, 22.17it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:08, 11.71it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   6%|▌         | 6/100 [00:00<00:07, 12.49it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:00<00:08, 10.87it/s]
#   2%|▏         | 162/10000 [00:00<00:15, 641.00it/s]
#   5%|▌         | 5/100 [00:00<00:07, 12.41it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:08, 11.98it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   6%|▌         | 6/100 [00:00<00:07, 12.89it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:00<00:08, 10.18it/s]
#   2%|▏         | 162/10000 [00:00<00:16, 611.54it/s]
#   5%|▌         | 5/100 [00:00<00:08, 10.87it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:07, 12.73it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   6%|▌         | 6/100 [00:00<00:07, 12.39it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:00<00:08, 10.91it/s]
#   2%|▏         | 162/10000 [00:00<00:13, 735.16it/s]
#   5%|▌         | 5/100 [00:00<00:08, 11.72it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:06, 15.13it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   6%|▌         | 6/100 [00:00<00:06, 14.68it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:00<00:08, 10.60it/s]
#   2%|▏         | 162/10000 [00:00<00:13, 756.30it/s]
#   5%|▌         | 5/100 [00:00<00:07, 12.87it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:07, 12.60it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   6%|▌         | 6/100 [00:00<00:07, 13.31it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:00<00:07, 11.56it/s]
#   2%|▏         | 162/10000 [00:00<00:17, 560.55it/s]
#   5%|▌         | 5/100 [00:00<00:08, 10.81it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:08, 10.95it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   6%|▌         | 6/100 [00:00<00:07, 12.51it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:00<00:08, 10.93it/s]
#   2%|▏         | 162/10000 [00:00<00:15, 616.86it/s]
#   5%|▌         | 5/100 [00:00<00:08, 11.68it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:06, 15.18it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   6%|▌         | 6/100 [00:00<00:06, 13.48it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:00<00:08, 10.37it/s]
#   2%|▏         | 162/10000 [00:00<00:14, 685.04it/s]
#   5%|▌         | 5/100 [00:00<00:11,  8.33it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:07, 13.94it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   6%|▌         | 6/100 [00:00<00:07, 13.04it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:00<00:07, 11.89it/s]
#   2%|▏         | 162/10000 [00:00<00:13, 715.23it/s]
#   5%|▌         | 5/100 [00:00<00:08, 11.43it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:09, 10.00it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   6%|▌         | 6/100 [00:00<00:07, 13.37it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:00<00:08, 10.93it/s]
#   2%|▏         | 162/10000 [00:00<00:14, 686.31it/s]
#   5%|▌         | 5/100 [00:00<00:08, 10.66it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:08, 11.63it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   6%|▌         | 6/100 [00:00<00:06, 13.87it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:00<00:07, 12.37it/s]
#   2%|▏         | 162/10000 [00:00<00:15, 654.47it/s]
#   5%|▌         | 5/100 [00:00<00:10,  9.25it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:07, 12.26it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   6%|▌         | 6/100 [00:00<00:07, 13.36it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:00<00:07, 11.68it/s]
#   2%|▏         | 162/10000 [00:00<00:23, 412.49it/s]
#   5%|▌         | 5/100 [00:00<00:08, 10.57it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:06, 14.85it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   6%|▌         | 6/100 [00:00<00:07, 12.97it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:00<00:08, 10.89it/s]
#   2%|▏         | 162/10000 [00:00<00:15, 621.87it/s]
#   5%|▌         | 5/100 [00:00<00:08, 11.17it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:07, 13.02it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   6%|▌         | 6/100 [00:00<00:07, 12.74it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:00<00:08, 10.90it/s]
#   2%|▏         | 162/10000 [00:00<00:15, 637.99it/s]
#   5%|▌         | 5/100 [00:00<00:10,  9.46it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:08, 11.45it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   6%|▌         | 6/100 [00:00<00:07, 12.93it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:00<00:07, 11.54it/s]
#   2%|▏         | 162/10000 [00:00<00:13, 729.96it/s]
#   5%|▌         | 5/100 [00:00<00:12,  7.76it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:07, 13.52it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   6%|▌         | 6/100 [00:00<00:08, 11.04it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:01<00:09,  9.94it/s]
#   2%|▏         | 162/10000 [00:00<00:14, 657.57it/s]
#   5%|▌         | 5/100 [00:00<00:12,  7.67it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:08, 11.57it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   6%|▌         | 6/100 [00:00<00:08, 11.20it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:00<00:08, 10.54it/s]
#   2%|▏         | 162/10000 [00:00<00:14, 672.74it/s]
#   5%|▌         | 5/100 [00:00<00:10,  9.36it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:07, 12.63it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   6%|▌         | 6/100 [00:00<00:07, 12.52it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:00<00:08, 10.65it/s]
#   2%|▏         | 162/10000 [00:00<00:14, 656.65it/s]
#   5%|▌         | 5/100 [00:00<00:09, 10.00it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:08, 12.17it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   6%|▌         | 6/100 [00:00<00:07, 12.17it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:00<00:07, 11.30it/s]
#   2%|▏         | 162/10000 [00:00<00:14, 670.25it/s]
#   5%|▌         | 5/100 [00:00<00:11,  8.55it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   1%|          | 1/100 [00:00<00:20,  4.78it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   7%|▋         | 7/100 [00:00<00:07, 11.67it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:01<00:09,  9.90it/s]
#   2%|▏         | 162/10000 [00:00<00:24, 396.99it/s]
#   5%|▌         | 5/100 [00:00<00:09, 10.23it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:07, 13.78it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   7%|▋         | 7/100 [00:00<00:08, 10.52it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:01<00:09,  9.76it/s]
#   2%|▏         | 162/10000 [00:00<00:15, 643.43it/s]
#   5%|▌         | 5/100 [00:00<00:09,  9.81it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:12,  7.65it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   7%|▋         | 7/100 [00:00<00:10,  9.27it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:01<00:11,  8.18it/s]
#   2%|▏         | 162/10000 [00:00<00:14, 676.26it/s]
#   5%|▌         | 5/100 [00:00<00:15,  6.03it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:07, 13.09it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   7%|▋         | 7/100 [00:00<00:12,  7.35it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:01<00:10,  8.21it/s]
#   2%|▏         | 162/10000 [00:00<00:14, 694.03it/s]
#   5%|▌         | 5/100 [00:00<00:16,  5.86it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:07, 13.33it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   6%|▌         | 6/100 [00:00<00:07, 13.42it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:00<00:07, 11.90it/s]
#   2%|▏         | 162/10000 [00:00<00:14, 674.29it/s]
#   5%|▌         | 5/100 [00:00<00:12,  7.87it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:13,  7.00it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   6%|▌         | 6/100 [00:00<00:08, 10.80it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:01<00:09,  9.59it/s]
#   2%|▏         | 162/10000 [00:00<00:14, 686.60it/s]
#   5%|▌         | 5/100 [00:00<00:12,  7.37it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:10,  9.30it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   6%|▌         | 6/100 [00:00<00:11,  8.27it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:01<00:10,  8.55it/s]
#   2%|▏         | 162/10000 [00:00<00:13, 715.21it/s]
#   5%|▌         | 5/100 [00:00<00:10,  8.88it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:07, 13.46it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   6%|▌         | 6/100 [00:00<00:06, 13.98it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:00<00:07, 11.82it/s]
#   2%|▏         | 162/10000 [00:00<00:13, 711.35it/s]
#   5%|▌         | 5/100 [00:00<00:11,  8.09it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:06, 14.32it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   6%|▌         | 6/100 [00:00<00:08, 11.74it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:00<00:08, 10.22it/s]
#   2%|▏         | 162/10000 [00:00<00:16, 610.62it/s]
#   5%|▌         | 5/100 [00:00<00:11,  8.58it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   1%|          | 1/100 [00:00<00:14,  6.85it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   7%|▋         | 7/100 [00:00<00:07, 11.89it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:00<00:08, 10.56it/s]
#   2%|▏         | 162/10000 [00:00<00:15, 644.30it/s]
#   5%|▌         | 5/100 [00:00<00:11,  8.29it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:09,  9.90it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   6%|▌         | 6/100 [00:00<00:08, 11.61it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:00<00:08, 11.08it/s]
#   2%|▏         | 162/10000 [00:00<00:15, 626.20it/s]
#   5%|▌         | 5/100 [00:00<00:12,  7.70it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:10,  9.27it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   6%|▌         | 6/100 [00:00<00:08, 10.78it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:00<00:08, 10.11it/s]
#   2%|▏         | 162/10000 [00:00<00:21, 454.68it/s]
#   5%|▌         | 5/100 [00:00<00:10,  8.80it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:06, 14.09it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   6%|▌         | 6/100 [00:00<00:08, 10.49it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:01<00:10,  8.75it/s]
#   2%|▏         | 162/10000 [00:00<00:14, 685.32it/s]
#   5%|▌         | 5/100 [00:00<00:10,  9.30it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:08, 12.13it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   6%|▌         | 6/100 [00:00<00:07, 11.83it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:00<00:08, 10.92it/s]
#   2%|▏         | 162/10000 [00:00<00:13, 736.97it/s]
#   5%|▌         | 5/100 [00:00<00:14,  6.43it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:10,  9.20it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   6%|▌         | 6/100 [00:00<00:10,  8.85it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:01<00:10,  8.49it/s]
#   2%|▏         | 162/10000 [00:00<00:19, 501.97it/s]
#   5%|▌         | 5/100 [00:00<00:11,  8.29it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:08, 10.93it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   6%|▌         | 6/100 [00:00<00:10,  9.27it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:01<00:09,  9.19it/s]
#   2%|▏         | 162/10000 [00:00<00:16, 590.32it/s]
#   5%|▌         | 5/100 [00:00<00:15,  6.09it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:09, 10.71it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   6%|▌         | 6/100 [00:00<00:10,  9.18it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:01<00:10,  8.51it/s]
#   2%|▏         | 162/10000 [00:00<00:13, 731.72it/s]
#   5%|▌         | 5/100 [00:00<00:11,  8.02it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:06, 15.25it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   6%|▌         | 6/100 [00:00<00:08, 10.81it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:00<00:08, 10.46it/s]
#   2%|▏         | 162/10000 [00:00<00:19, 511.04it/s]
#   5%|▌         | 5/100 [00:00<00:11,  8.09it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:12,  7.97it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   6%|▌         | 6/100 [00:00<00:07, 12.03it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:00<00:08, 11.10it/s]
#   2%|▏         | 162/10000 [00:00<00:13, 723.87it/s]
#   5%|▌         | 5/100 [00:00<00:12,  7.40it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:10,  9.37it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   7%|▋         | 7/100 [00:00<00:08, 11.36it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:00<00:08, 10.04it/s]
#   2%|▏         | 162/10000 [00:00<00:15, 647.70it/s]
#   5%|▌         | 5/100 [00:00<00:12,  7.40it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:14,  6.85it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   7%|▋         | 7/100 [00:00<00:08, 10.64it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:01<00:09,  9.81it/s]
#   2%|▏         | 162/10000 [00:00<00:16, 612.95it/s]
#   5%|▌         | 5/100 [00:00<00:14,  6.34it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:14,  6.89it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   7%|▋         | 7/100 [00:00<00:12,  7.33it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:01<00:12,  7.23it/s]
#   2%|▏         | 162/10000 [00:00<00:21, 456.29it/s]
#   5%|▌         | 5/100 [00:00<00:14,  6.69it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:07, 12.49it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   6%|▌         | 6/100 [00:00<00:08, 11.15it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:00<00:08, 10.34it/s]
#   2%|▏         | 162/10000 [00:00<00:16, 595.66it/s]
#   5%|▌         | 5/100 [00:00<00:14,  6.78it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:12,  7.99it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   6%|▌         | 6/100 [00:00<00:08, 10.87it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:01<00:10,  8.44it/s]
#   2%|▏         | 162/10000 [00:00<00:14, 689.36it/s]
#   5%|▌         | 5/100 [00:00<00:14,  6.36it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:07, 13.66it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   6%|▌         | 6/100 [00:00<00:07, 13.40it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# ...
#   probs = gates+np.log(event_probs)
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   6%|▌         | 6/100 [00:00<00:04, 20.42it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:00<00:04, 20.92it/s]
#   2%|▏         | 162/10000 [00:00<00:10, 968.07it/s]
#   5%|▌         | 5/100 [00:00<00:17,  5.52it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:04, 19.93it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   7%|▋         | 7/100 [00:00<00:04, 19.85it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:00<00:05, 17.80it/s]
#   2%|▏         | 162/10000 [00:00<00:10, 899.89it/s]
#   5%|▌         | 5/100 [00:00<00:15,  5.94it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   6%|▌         | 6/100 [00:00<00:04, 19.96it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:00<00:04, 18.58it/s]
#   2%|▏         | 162/10000 [00:00<00:08, 1108.49it/s]
#   5%|▌         | 5/100 [00:00<00:16,  5.89it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   6%|▌         | 6/100 [00:00<00:04, 20.87it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:00<00:04, 18.73it/s]
#   2%|▏         | 162/10000 [00:00<00:09, 1083.96it/s]
#   5%|▌         | 5/100 [00:00<00:17,  5.37it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:04, 19.75it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   5%|▌         | 5/100 [00:00<00:04, 20.22it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:00<00:04, 18.21it/s]
#   2%|▏         | 162/10000 [00:00<00:10, 940.63it/s]
#   5%|▌         | 5/100 [00:00<00:18,  5.17it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:04, 19.73it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   7%|▋         | 7/100 [00:00<00:04, 19.78it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:00<00:04, 18.32it/s]
#   2%|▏         | 162/10000 [00:00<00:09, 990.83it/s]
#   5%|▌         | 5/100 [00:00<00:18,  5.03it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   6%|▌         | 6/100 [00:00<00:04, 20.89it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:00<00:04, 19.04it/s]
#   2%|▏         | 162/10000 [00:00<00:09, 1047.68it/s]
#   5%|▌         | 5/100 [00:00<00:17,  5.34it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   6%|▌         | 6/100 [00:00<00:04, 20.67it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:00<00:04, 18.67it/s]
#   2%|▏         | 162/10000 [00:00<00:12, 768.24it/s]
#   5%|▌         | 5/100 [00:00<00:18,  5.04it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:04, 19.62it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   7%|▋         | 7/100 [00:00<00:04, 19.63it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:00<00:05, 16.62it/s]
#   2%|▏         | 162/10000 [00:00<00:11, 887.41it/s]
#   5%|▌         | 5/100 [00:01<00:19,  4.93it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   6%|▌         | 6/100 [00:00<00:04, 21.20it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:00<00:04, 18.66it/s]
#   2%|▏         | 162/10000 [00:00<00:09, 1043.16it/s]
#   5%|▌         | 5/100 [00:01<00:19,  4.82it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:05, 16.63it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   5%|▌         | 5/100 [00:00<00:04, 19.00it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:00<00:04, 18.13it/s]
#   2%|▏         | 162/10000 [00:00<00:09, 999.83it/s]
#   5%|▌         | 5/100 [00:00<00:18,  5.15it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   6%|▌         | 6/100 [00:00<00:04, 20.57it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:00<00:04, 18.54it/s]
#   2%|▏         | 162/10000 [00:00<00:13, 708.75it/s]
#   5%|▌         | 5/100 [00:01<00:20,  4.69it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:05, 18.13it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   7%|▋         | 7/100 [00:00<00:04, 19.19it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:00<00:05, 17.71it/s]
#   2%|▏         | 162/10000 [00:00<00:09, 993.75it/s]
#   5%|▌         | 5/100 [00:01<00:21,  4.41it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   6%|▌         | 6/100 [00:00<00:04, 19.70it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:00<00:04, 18.37it/s]
#   2%|▏         | 162/10000 [00:00<00:09, 1086.98it/s]
#   5%|▌         | 5/100 [00:00<00:18,  5.00it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:05, 17.41it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   7%|▋         | 7/100 [00:00<00:04, 19.98it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:00<00:04, 18.24it/s]
#   2%|▏         | 162/10000 [00:00<00:13, 753.60it/s]
#   5%|▌         | 5/100 [00:01<00:19,  4.94it/s]
#   0%|          | 0/100 [00:00<?, ?it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: divide by zero encountered in log
#   probs = gates+np.log(event_probs)
#   2%|▏         | 2/100 [00:00<00:05, 17.91it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:105: RuntimeWarning: invalid value encountered in log
#   probs = gates+np.log(event_probs)
#   7%|▋         | 7/100 [00:00<00:04, 19.93it/s]C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:58: RuntimeWarning: invalid value encountered in power
#   return spl(ts)**risks
# C:\My_Programs\Anaconda\envs\CSMDRMP\lib\site-packages\auton_survival\models\dcm\dcm_utilities.py:53: RuntimeWarning: invalid value encountered in power
#   s0ts = (-risks)*(spl(ts)**(risks-1))
#  10%|█         | 10/100 [00:00<00:04, 18.06it/s]
#   2%|▏         | 162/10000 [00:00<00:08, 1111.69it/s]
#   5%|▌         | 5/100 [00:00<00:17,  5.52it/s]

# %%
def create_estimates_dict(estimates_list,
                          num_groups=3,
                          total_estimates=None):
    """
    Create the estimates_dict for compute_bias from overall and per-group estimates lists.
    :param overall_estimates: List of estimated effects from replicates.
    :param num_groups: Number of groups to use.
    :param total_estimates: List of estimated effects for total.
    :return estimates_dict (dict): {'overall': overall_estimates, group_id: list_for_group, ...}
    """
    if total_estimates is None:
        estimates_dict = {"average": estimates_list}

        for i in range(num_groups):
            estimates_dict[f"group {i}"] = estimates_list
    else:
        estimates_dict = {"average": total_estimates}

        for i in range(num_groups):
            estimates_dict[f"group {i}"] = [row[i] for row in estimates_list]

    return estimates_dict

# %%
CoxPH_estimated_dict = create_estimates_dict(CoxPH_estimated)
CoxPH_IPTW_estimated_dict = create_estimates_dict(CoxPH_IPTW_estimated)
PSM_CoxPH_estimated_dict = create_estimates_dict(PSM_CoxPH_estimated)
DSM_estimated_dict = create_estimates_dict(DSM_estimated)
DCM_latent_estimated_dict = create_estimates_dict(DCM_latent_estimated, total_estimates=DCM_total_estimated)

# %%
true_value = save_dict["beta_A_k"]
avg_true_value = np.mean(true_value)
true_value_dict = {"average": avg_true_value,
                   "group 0": true_value[0],
                   "group 1": true_value[1],
                   "group 2": true_value[2]}

# %%
true_value_dict
# Out:
# {'average': -0.4744313046555682,
#  'group 0': -0.5822332178326662,
#  'group 1': -0.5786429977229298,
#  'group 2': -0.2624176984111085}

# %% [markdown]
# ## Different metrics

# %%
def compute_bias(estimates_dict, true_values_dict):
    """
    Compute absolute and relative bias from a dict of estimates and true values
    :param estimates_dict: dict of estimated effects
    :param true_values_dict: dict of true values
    :return: biases
    """
    biases = {}
    for key in true_values_dict:

        true_value = true_values_dict[key]
        estimates = estimates_dict[key]

        mean_est = np.mean(estimates)
        abs_bias = np.abs(mean_est - true_value)

        if true_value == 0:
            rel_bias = None
        else:
            rel_bias = (mean_est - true_value) / true_value

        biases[key] = {"abs_bias": abs_bias, "rel_bias": rel_bias}

    return biases

# %%
def compute_mse(estimates_dict, true_values_dict):
    """
    Compute MSE from a dict of estimates and true values,
    to emphasize latent groups by computing per group and overall.
    :param estimates_dict: dict of estimated effects
    :param true_values_dict: dict of true values
    :return
    """
    mses = {}
    for key in estimates_dict:

        estimates = estimates_dict[key]
        true_value = true_values_dict[key]

        mse = np.mean([(e - true_value) ** 2 for e in estimates])

        mses[key] = mse

    return mses

# %% [markdown]
# ## Get df

# %%
"""
compute_bias
"""
CoxPH_bias = compute_bias(CoxPH_estimated_dict, true_value_dict)
CoxPH_IPTW_bias = compute_bias(CoxPH_IPTW_estimated_dict, true_value_dict)
PSM_CoxPH_bias = compute_bias(PSM_CoxPH_estimated_dict, true_value_dict)
DSM_estimated_bias = compute_bias(DSM_estimated_dict, true_value_dict)
DCM_latent_bias = compute_bias(DCM_latent_estimated_dict, true_value_dict)

# %%
"""
compute_mse
"""
CoxPH_mse = compute_mse(CoxPH_estimated_dict, true_value_dict)
CoxPH_IPTW_mse = compute_mse(CoxPH_IPTW_estimated_dict, true_value_dict)
PSM_CoxPH_mse = compute_mse(PSM_CoxPH_estimated_dict, true_value_dict)
DSM_estimated_mse = compute_mse(DSM_estimated_dict, true_value_dict)
DCM_latent_mse = compute_mse(DCM_latent_estimated_dict, true_value_dict)

# %%
df_dict = {"Model Name": ["CoxPH", "CoxPH_IPTW", "PSM_CoxPH", "DSM", "DCM"]}
for key in true_value_dict:

    df_dict[key + "_abs_bias"] = [
        CoxPH_bias[key]["abs_bias"],
        CoxPH_IPTW_bias[key]["abs_bias"],
        PSM_CoxPH_bias[key]["abs_bias"],
        DSM_estimated_bias[key]["abs_bias"],
        DCM_latent_bias[key]["abs_bias"]
    ]

    df_dict[key + "_rel_bias"] = [
        CoxPH_bias[key]["rel_bias"],
        CoxPH_IPTW_bias[key]["rel_bias"],
        PSM_CoxPH_bias[key]["rel_bias"],
        DSM_estimated_bias[key]["rel_bias"],
        DCM_latent_bias[key]["rel_bias"]
    ]

    df_dict[key + "_mse"] = [
        CoxPH_mse[key],
        CoxPH_IPTW_mse[key],
        PSM_CoxPH_mse[key],
        DSM_estimated_mse[key],
        DCM_latent_mse[key]
    ]

# %%
pd.DataFrame(df_dict)
# Out:
#    Model Name  average_abs_bias  average_rel_bias  average_mse  \
# 0       CoxPH          0.591213         -1.246151     0.349536
# 1  CoxPH_IPTW          0.205300         -0.432730     0.042328
# 2   PSM_CoxPH          0.166778         -0.351532     0.027852
# 3         DSM          0.466923         -0.984174     0.218604
# 4         DCM          0.348243         -0.734023     0.121692
#
#    group 0_abs_bias  group 0_rel_bias  group 0_mse  group 1_abs_bias  \
# 0          0.699015         -1.200575     0.488625          0.695425
# 1          0.313102         -0.537761     0.098213          0.309512
# 2          0.274580         -0.471597     0.075431          0.270989
# 3          0.574725         -0.987104     0.330896          0.571134
# 4          0.561926         -0.965121     0.316419          0.538371
#
#    group 1_rel_bias  group 1_mse  group 2_abs_bias  group 2_rel_bias  \
# 0         -1.201820     0.483618          0.379199         -1.445022
# 1         -0.534893     0.095978          0.006713          0.025582
# 2         -0.468319     0.073473          0.045236          0.172381
# 3         -0.987024     0.326782          0.254909         -0.971387
# 4         -0.930402     0.290028          1.904072          7.255881
#
#    group 2_mse
# 0     0.143795
# 1     0.000225
# 2     0.002084
# 3     0.065566
# 4     3.655028
